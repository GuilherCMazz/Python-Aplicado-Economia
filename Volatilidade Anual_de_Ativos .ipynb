# %%
! pip install yfinance

# %% [markdown]
# #Importando Bibliotecas

# %%
import numpy as np
import yfinance as yf

# %% [markdown]
# # Definindo os Parâmetros

# %%
ativos=['VALE3.SA','BRML3.SA','CIEL3.SA']

# %%
pesos=np.array([0.2,0.3,0.1])
portfolio=yf.download(ativos,start='2020-12-19', end='2022-12-19')['Adj Close']
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
portfolio.head()
# Out:
#              BRML3.SA  CIEL3.SA   VALE3.SA
# Date
# 2020-12-21  10.033001  3.134190  67.369621
# 2020-12-22   9.794357  3.046886  67.431664
# 2020-12-23   9.953453  3.081808  67.757416
# 2020-12-28  10.192097  3.326257  67.718643
# 2020-12-29  10.003171  3.343718  67.532494

# %%
portfolio_retornos=portfolio.pct_change()
portfolio_retornos
# Out:
#             BRML3.SA  CIEL3.SA  VALE3.SA
# Date
# 2020-12-21       NaN       NaN       NaN
# 2020-12-22 -0.023786 -0.027855  0.000921
# 2020-12-23  0.016244  0.011461  0.004831
# 2020-12-28  0.023976  0.079320 -0.000572
# 2020-12-29 -0.018536  0.005249 -0.002749
# ...              ...       ...       ...
# 2022-12-12 -0.024540  0.020690 -0.029862
# 2022-12-13 -0.020126 -0.029279  0.004219
# 2022-12-14  0.008986  0.062645  0.008473
# 2022-12-15 -0.001272  0.034934  0.003222
# 2022-12-16 -0.019108 -0.033755 -0.017093
#
# [494 rows x 3 columns]

# %%
portfolio_retornos.dropna(inplace=True)
portfolio_retornos
# Out:
#             BRML3.SA  CIEL3.SA  VALE3.SA
# Date
# 2020-12-22 -0.023786 -0.027855  0.000921
# 2020-12-23  0.016244  0.011461  0.004831
# 2020-12-28  0.023976  0.079320 -0.000572
# 2020-12-29 -0.018536  0.005249 -0.002749
# 2020-12-30 -0.015905  0.059870  0.004364
# ...              ...       ...       ...
# 2022-12-12 -0.024540  0.020690 -0.029862
# 2022-12-13 -0.020126 -0.029279  0.004219
# 2022-12-14  0.008986  0.062645  0.008473
# 2022-12-15 -0.001272  0.034934  0.003222
# 2022-12-16 -0.019108 -0.033755 -0.017093
#
# [493 rows x 3 columns]

# %%
# Calculando Matriz de Covariância

cov_portfolio=portfolio_retornos.cov()
cov_portfolio
# Out:
#           BRML3.SA  CIEL3.SA  VALE3.SA
# BRML3.SA  0.000496  0.000262  0.000017
# CIEL3.SA  0.000262  0.000944  0.000008
# VALE3.SA  0.000017  0.000008  0.000551

# %% [markdown]
# # Calculando a Volatilidade

# %%
vol_diaria=np.sqrt(np.dot(pesos.T,np.dot(cov_portfolio,pesos)))
vol_diaria
# Out:
# 0.011955427233916294

# %%
vol_anualizada=vol_diaria*(np.sqrt(252))
vol_anualizada
# Out:
# 0.18978652367082807

# %% [markdown]
# # A volatididade desses 3 ativos com os pesos estabelecidos é de 19% no periodo de 2020 a 2022.
#
# # A volatilidade é uma medida que exprime a próclise do risco da carteira, ou seja, quanto maior a volatilidade, mais os preços variam e teoricamente corremos mais risco.
